# %% [markdown]
# # STITCHV2 Tutorial Pointer
#
# The canonical tutorial lives at `docs/stitchv2_tutorial.md`.
#
# Use `docs/CLI_REFERENCE.md` for the complete command-line flag reference and `docs/README.md` for the production documentation index.
#
# This notebook is intentionally a pointer only, so package-source browsing does not expose stale tutorial text.
